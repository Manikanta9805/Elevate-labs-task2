# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df=pd.read_csv(r"C:\Users\manik\OneDrive\Desktop\Elevate labs tasks\cleaned_titanic_data.csv")
print(df.describe())
print(df.info())
# Out:
#        PassengerId    Survived     Pclass         Age       SibSp       Parch  \
# count   775.000000  775.000000  775.00000  775.000000  775.000000  775.000000
# mean    445.806452    0.339355    2.48000   -0.047099    0.437419    0.340645
# std     260.116285    0.473796    0.73439    0.982304    0.899838    0.785914
# min       1.000000    0.000000    1.00000   -2.224156    0.000000    0.000000
# 25%     213.500000    0.000000    2.00000   -0.565736    0.000000    0.000000
# 50%     450.000000    0.000000    3.00000   -0.104637    0.000000    0.000000
# 75%     670.500000    1.000000    3.00000    0.356462    1.000000    0.000000
# max     891.000000    1.000000    3.00000    3.891554    5.000000    6.000000
#
#              Fare
# count  775.000000
# mean    -0.289579
# std      0.273391
# min     -0.648422
# 25%     -0.489442
# 50%     -0.386671
# 75%     -0.124920
# max      0.660333
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 775 entries, 0 to 774
# ...

# %%
plt.figure(figsize=(10,5))
sns.histplot(df['Age'].dropna(),bins=30,kde=True)
plt.title("Distribution of Age")
plt.show()

# %%
sns.boxplot(x='Pclass', y='Fare', data=df)
plt.title("Fare distribution by passenger class")
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(numeric_only=True),annot=True,cmap='coolwarm',fmt='.2f')
plt.title("Correlation Matrix")
plt.show()

# %%
sns.pairplot(df[['Age','Fare','Pclass','Survived']].dropna(),hue='Survived')
plt.suptitle("Pairplot",y=1.02)
plt.show()

# %%
sns.countplot(x='Sex', hue='Survived', data=df)
plt.title("Survival Count by Gender")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 sns.countplot(x='Sex', hue='Survived', data=df)
#       2 plt.title("Survival Count by Gender")
#       3 plt.show()
#
# File c:\Users\manik\anaconda3\Lib\site-packages\seaborn\categorical.py:2631, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, hue_norm, stat, width, dodge, gap, log_scale, native_scale, formatter, legend, ax, **kwargs)
#    2628 elif x is not None and y is not None:
#    2629     raise TypeError("Cannot pass values for both `x` and `y`.")
# -> 2631 p = _CategoricalAggPlotter(
#    2632     data=data,
#    2633     variables=dict(x=x, y=y, hue=hue),
#    2634     order=order,
#    2635     orient=orient,
#    2636     color=color,
#    2637     legend=legend,
#    2638 )
#    2640 if ax is None:
#    2641     ax = plt.gca()
#
# ...

# %%
print(df.columns.tolist())
# Out:
# ['Passengerid', 'Survived', 'Pclass', 'Age', 'Sibsp', 'Parch', 'Fare', 'Sex_male', 'Embarked_q', 'Embarked_s']

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a new 'Sex' column from 'Sex_male'
df['Sex'] = df['Sex_male'].apply(lambda x: 'Male' if x == 1 else 'Female')

# Now plot
sns.countplot(x='Sex', hue='Survived', data=df)
plt.title("Survival Count by Gender")
plt.xlabel("Sex")
plt.ylabel("Count")
plt.legend(title="Survived", labels=["No", "Yes"])
plt.show()

# %%
No code was provided to improve.
